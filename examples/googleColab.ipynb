# %% [markdown]
# <a href="https://colab.research.google.com/github/dNodal0/dotfiles/blob/master/examples/googleColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing the OpenBB Platform in Google Colab
#
# This notebook will install the OpenBB Platform, fetch some data and prepare it for display as a bar chart.
#
# Sign up for a free account here: https://my.openbb.co

# %%
# Install the OpenBB Platform with all available extensions.
# Messages indicating package version conflicts at the end of installation can be safely ignored.

# !pip install openbb[all]

# There is also a nightly distribution available, openbb-nightly
# Out:
# Requirement already satisfied: openbb[all] in /usr/local/lib/python3.11/dist-packages (4.4.3)
# Requirement already satisfied: openbb-alpha-vantage<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-benzinga<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-biztoc<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.1)
# Requirement already satisfied: openbb-bls<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.1.1)
# Requirement already satisfied: openbb-cboe<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-cftc<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.1.0)
# Requirement already satisfied: openbb-charting<3.0.0,>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (2.3.2)
# Requirement already satisfied: openbb-commodity<2.0.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.3.0)
# Requirement already satisfied: openbb-core<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.4)
# Requirement already satisfied: openbb-crypto<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-currency<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-deribit<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.0.0)
# Requirement already satisfied: openbb-derivatives<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-ecb<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.1)
# Requirement already satisfied: openbb-econdb<2.0.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.3.0)
# Requirement already satisfied: openbb-econometrics<2.0.0,>=1.5.2 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.5.2)
# Requirement already satisfied: openbb-economy<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.1)
# Requirement already satisfied: openbb-equity<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-etf<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-federal-reserve<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.1)
# Requirement already satisfied: openbb-finra<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-finviz<2.0.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.3.0)
# Requirement already satisfied: openbb-fixedincome<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.2)
# Requirement already satisfied: openbb-fmp<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.1)
# Requirement already satisfied: openbb-fred<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.3)
# Requirement already satisfied: openbb-government-us<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-imf<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.1.0)
# Requirement already satisfied: openbb-index<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-intrinio<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-multpl<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.1.0)
# Requirement already satisfied: openbb-nasdaq<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-news<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-oecd<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-platform-api<2.0.0,>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.1.5)
# Requirement already satisfied: openbb-polygon<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-quantitative<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.2)
# Requirement already satisfied: openbb-regulators<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.1)
# Requirement already satisfied: openbb-sec<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.2)
# Requirement already satisfied: openbb-seeking-alpha<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-stockgrid<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-technical<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.2)
# Requirement already satisfied: openbb-tiingo<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-tmx<2.0.0,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.3.1)
# Requirement already satisfied: openbb-tradier<2.0.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.3.0)
# Requirement already satisfied: openbb-tradingeconomics<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-us-eia<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.1.0)
# Requirement already satisfied: openbb-wsj<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.0)
# Requirement already satisfied: openbb-yfinance<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb[all]) (1.4.2)
# Requirement already satisfied: aiohttp-client-cache<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from openbb-cboe<2.0.0,>=1.4.0->openbb[all]) (0.11.1)
# Requirement already satisfied: aiosqlite<0.21.0,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from openbb-cboe<2.0.0,>=1.4.0->openbb[all]) (0.20.0)
# Requirement already satisfied: nbformat<6.0.0,>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from openbb-charting<3.0.0,>=2.3.2->openbb[all]) (5.10.4)
# Requirement already satisfied: pandas-ta-openbb<0.5.0,>=0.4.20 in /usr/local/lib/python3.11/dist-packages (from openbb-charting<3.0.0,>=2.3.2->openbb[all]) (0.4.21)
# Requirement already satisfied: plotly<6.0.0,>=5.24.1 in /usr/local/lib/python3.11/dist-packages (from openbb-charting<3.0.0,>=2.3.2->openbb[all]) (5.24.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.11 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (3.11.15)
# Requirement already satisfied: fastapi<0.116,>=0.115 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.115.12)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (8.6.1)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (2.2.2)
# Requirement already satisfied: posthog<4.0.0,>=3.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (3.24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (2.11.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (2.10.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.1.0)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.0.20)
# Requirement already satisfied: requests<3.0.0,>=2.32.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (2.32.3)
# Requirement already satisfied: ruff<0.8,>=0.7 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.7.4)
# Requirement already satisfied: uuid7<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.1.0)
# Requirement already satisfied: uvicorn<0.35.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.34.0)
# Requirement already satisfied: websockets<16.0,>=15.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.3->openbb[all]) (15.0.1)
# Requirement already satisfied: async-lru<3.0.0,>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from openbb-deribit<2.0.0,>=1.0.0->openbb[all]) (2.0.5)
# Requirement already satisfied: xmltodict<0.14.0,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from openbb-ecb<2.0.0,>=1.4.1->openbb[all]) (0.13.0)
# Requirement already satisfied: arch<8.0,>=7.2 in /usr/local/lib/python3.11/dist-packages (from openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (7.2.0)
# Requirement already satisfied: linearmodels<7,>=6 in /usr/local/lib/python3.11/dist-packages (from openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (6.1)
# Requirement already satisfied: finvizfinance<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-finviz<2.0.0,>=1.3.0->openbb[all]) (1.1.0)
# Requirement already satisfied: random-user-agent<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from openbb-government-us<2.0.0,>=1.4.0->openbb[all]) (1.0.1)
# Requirement already satisfied: requests-cache<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-intrinio<2.0.0,>=1.4.0->openbb[all]) (1.2.1)
# Requirement already satisfied: nasdaq-data-link<2.0.0,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from openbb-nasdaq<2.0.0,>=1.4.0->openbb[all]) (1.0.4)
# Requirement already satisfied: defusedxml<0.9.0,>=0.8.0rc2 in /usr/local/lib/python3.11/dist-packages (from openbb-oecd<2.0.0,>=1.4.0->openbb[all]) (0.8.0rc2)
# Requirement already satisfied: urllib3>1.26.16 in /usr/local/lib/python3.11/dist-packages (from openbb-oecd<2.0.0,>=1.4.0->openbb[all]) (2.3.0)
# Requirement already satisfied: deepdiff in /usr/local/lib/python3.11/dist-packages (from openbb-platform-api<2.0.0,>=1.1.5->openbb[all]) (8.4.2)
# Requirement already satisfied: beautifulsoup4<5.0,>=4.12 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.2->openbb[all]) (4.13.3)
# Requirement already satisfied: inscriptis<3.0.0,>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.2->openbb[all]) (2.6.0)
# Requirement already satisfied: lxml<6.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.2->openbb[all]) (5.3.1)
# Requirement already satisfied: trafilatura<3.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.2->openbb[all]) (2.0.0)
# Requirement already satisfied: pytest-freezegun<0.5.0,>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb-stockgrid<2.0.0,>=1.4.0->openbb[all]) (0.4.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from openbb-technical<2.0.0,>=1.4.2->openbb[all]) (1.6.1)
# Requirement already satisfied: exchange-calendars<5.0.0,>=4.5.4 in /usr/local/lib/python3.11/dist-packages (from openbb-tmx<2.0.0,>=1.3.1->openbb[all]) (4.10)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from openbb-us-eia<2.0.0,>=1.1.0->openbb[all]) (3.1.5)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from openbb-us-eia<2.0.0,>=1.1.0->openbb[all]) (2.0.1)
# Requirement already satisfied: yfinance<0.3.0,>=0.2.55 in /usr/local/lib/python3.11/dist-packages (from openbb-yfinance<2.0.0,>=1.4.2->openbb[all]) (0.2.55)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.3->openbb[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.3->openbb[all]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.3->openbb[all]) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.18.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-cboe<2.0.0,>=1.4.0->openbb[all]) (2.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-cboe<2.0.0,>=1.4.0->openbb[all]) (1.4.3)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.11/dist-packages (from aiosqlite<0.21.0,>=0.20.0->openbb-cboe<2.0.0,>=1.4.0->openbb[all]) (4.13.1)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (2.0.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.11/dist-packages (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (1.14.1)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.11/dist-packages (from arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (0.14.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0,>=4.12->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (2.6)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.1->openbb[all]) (2.2.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.1->openbb[all]) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.1->openbb[all]) (2025.2)
# Requirement already satisfied: korean_lunar_calendar in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5.0.0,>=4.5.4->openbb-tmx<2.0.0,>=1.3.1->openbb[all]) (0.3.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.46.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.4.3->openbb[all]) (3.21.0)
# Requirement already satisfied: mypy-extensions>=0.4 in /usr/local/lib/python3.11/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (1.0.0)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (3.0.12)
# Requirement already satisfied: pyhdfe>=0.1 in /usr/local/lib/python3.11/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (0.2.0)
# Requirement already satisfied: formulaic>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (1.1.1)
# Requirement already satisfied: setuptools-scm<9.0.0,>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (8.2.0)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.4.0->openbb[all]) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.4.0->openbb[all]) (2.9.0.post0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from nasdaq-data-link<2.0.0,>=1.0.4->openbb-nasdaq<2.0.0,>=1.4.0->openbb[all]) (10.6.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.11/dist-packages (from nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (5.7.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl<4.0.0,>=3.1.5->openbb-us-eia<2.0.0,>=1.1.0->openbb[all]) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.4.3->openbb[all]) (2025.2)
# Requirement already satisfied: numba>=0.59.0 in /usr/local/lib/python3.11/dist-packages (from pandas-ta-openbb<0.5.0,>=0.4.20->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (0.60.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly<6.0.0,>=5.24.1->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly<6.0.0,>=5.24.1->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (24.2)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.4.0)
# Requirement already satisfied: freezegun>0.3 in /usr/local/lib/python3.11/dist-packages (from pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.0->openbb[all]) (1.5.1)
# Requirement already satisfied: pytest>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.0->openbb[all]) (8.3.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.3->openbb[all]) (2025.1.31)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.4.0->openbb[all]) (24.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.4.0->openbb[all]) (4.3.7)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.6.0->openbb-technical<2.0.0,>=1.4.2->openbb[all]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.6.0->openbb-technical<2.0.0,>=1.4.2->openbb[all]) (3.6.0)
# Requirement already satisfied: courlan>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (1.3.2)
# Requirement already satisfied: htmldate>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (1.9.3)
# Requirement already satisfied: justext>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (3.0.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.0->openbb-core<2.0.0,>=1.4.3->openbb[all]) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.0->openbb-core<2.0.0,>=1.4.3->openbb[all]) (0.14.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3.0,>=0.2.55->openbb-yfinance<2.0.0,>=1.4.2->openbb[all]) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3.0,>=0.2.55->openbb-yfinance<2.0.0,>=1.4.2->openbb[all]) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3.0,>=0.2.55->openbb-yfinance<2.0.0,>=1.4.2->openbb[all]) (3.17.9)
# Requirement already satisfied: orderly-set<6,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from deepdiff->openbb-platform-api<2.0.0,>=1.1.5->openbb[all]) (5.4.0)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (2.17.0)
# Requirement already satisfied: tld>=0.13 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (0.13)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=1.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (1.17.2)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (1.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.0->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (0.24.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.59.0->pandas-ta-openbb<0.5.0,>=0.4.20->openbb-charting<3.0.0,>=2.3.2->openbb[all]) (0.43.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.0->openbb[all]) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=3.0.0->pytest-freezegun<0.5.0,>=0.4.2->openbb-stockgrid<2.0.0,>=1.4.0->openbb[all]) (1.5.0)
# Requirement already satisfied: setuptools>=61 in /usr/local/lib/python3.11/dist-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels<7,>=6->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (75.2.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.3->openbb[all]) (4.9.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.12->arch<8.0,>=7.2->openbb-econometrics<2.0.0,>=1.5.2->openbb[all]) (1.0.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.3->openbb[all]) (1.3.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (5.3.1)
# Requirement already satisfied: lxml_html_clean in /usr/local/lib/python3.11/dist-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.2->openbb[all]) (0.4.2)

# %%
# Before running this cell, restart the runtime by selecting, "Restart runtime", from the "Runtime" menu.

# Import statements - for many scenarios, the only import needed will be `from openbb import obb`
from typing import Literal
from IPython.display import display
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import pandas_ta as ta
from datetime import datetime
from plotly import graph_objects as go

from openbb import obb
# Out:
# Extensions to add: fred@1.4.3
# Extensions to remove: fred@1.4.1, store@0.1.1, udf_yfinance@1.0.0
#
# Building...

# %%
# Login to OpenBB Hub to retrieve stored API keys.
# https://my.openbb.co/app/platform/pat
# https://my.openbb.co/app/platform/api-keys

obb.account.login(pat="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhdXRoX3Rva2VuIjoiaExzZzNTcWY5S1VDR0l2ODhMYnY2V2JteXVRWTU1MEc0V0F4MWRYTSIsImV4cCI6MTc2MDUzNjU4M30.mN-2ao0Tm_tQstsVjGdnUPAxs4z8lhmQp1meOo6vlZ0")

# This is not required

# %%
# Verify that the credentials from Hub were loaded successfully.

obb.user.credentials
# Out:
# Credentials
#
# alpha_vantage_api_key: None
# benzinga_api_key: None
# biztoc_api_key: None
# bls_api_key: None
# cftc_app_token: None
# econdb_api_key: None
# eia_api_key: None
# fmp_api_key: None
# fred_api_key: None
# intrinio_api_key: None
# nasdaq_api_key: None
# polygon_api_key: None
# tiingo_token: None
# tradier_account_type: None
# tradier_api_key: None
# tradingeconomics_api_key: None

# %%
# Set the output preference, if desired. The examples below use Pandas DataFrames.

obb.user.preferences.output_type = "dataframe"

# %%
# Get Some Data
symbol = "SPY"

options = obb.derivatives.options.chains(symbol, provider="cboe")

options
# Out:
#       underlying_symbol  underlying_price     contract_symbol  expiration  \
# 0                   SPY            533.94  SPY250414C00300000  2025-04-14
# 1                   SPY            533.94  SPY250414P00300000  2025-04-14
# 2                   SPY            533.94  SPY250414C00305000  2025-04-14
# 3                   SPY            533.94  SPY250414P00305000  2025-04-14
# 4                   SPY            533.94  SPY250414C00310000  2025-04-14
# ...                 ...               ...                 ...         ...
# 11245               SPY            533.94  SPY271217P00905000  2027-12-17
# 11246               SPY            533.94  SPY271217C00910000  2027-12-17
# 11247               SPY            533.94  SPY271217P00910000  2027-12-17
# 11248               SPY            533.94  SPY271217C00915000  2027-12-17
# 11249               SPY            533.94  SPY271217P00915000  2027-12-17
#
#        dte  strike option_type  open_interest  volume  theoretical_price  ...  \
# 0        2   300.0        call              0       0           234.4754  ...
# 1        2   300.0         put           2051     358             0.0003  ...
# 2        2   305.0        call              0       0           229.4754  ...
# 3        2   305.0         put             62       2             0.0003  ...
# 4        2   310.0        call              5       0           224.4755  ...
# ...    ...     ...         ...            ...     ...                ...  ...
# 11245  979   905.0         put              0       0           370.5250  ...
# 11246  979   910.0        call            543       2             1.5138  ...
# 11247  979   910.0         put              0       0           375.5250  ...
# 11248  979   915.0        call           2616      30             1.4395  ...
# 11249  979   915.0         put              0       0           380.5250  ...
#
#         low  prev_close change  change_percent  implied_volatility   delta  \
# 0      0.00  218.820000  0.000    0.000000e+00              0.0000  1.0000
# 1      0.01    0.010000  0.000    2.235170e-08              1.8634  0.0000
# 2      0.00  213.790001  0.000    0.000000e+00              0.0000  1.0000
# 3      0.01    0.010000  0.000    2.235170e-08              1.8126  0.0000
# 4      0.00  208.959999  0.000    0.000000e+00              0.0000  1.0000
# ...     ...         ...    ...             ...                 ...     ...
# 11245  0.00  386.455002  0.000    0.000000e+00              0.3061 -1.0000
# 11246  1.50    1.605000 -0.105   -6.542060e-02              0.1438  0.0357
# 11247  0.00  391.455002  0.000    0.000000e+00              0.3086 -1.0000
# 11248  1.41    1.505000 -0.075   -4.983390e-02              0.1414  0.0342
# 11249  0.00  396.455002  0.000    0.000000e+00              0.3112 -1.0000
#
#         gamma   theta    vega     rho
# 0      0.0000 -0.0003  0.0000  0.0005
# 1      0.0000 -0.0003  0.0000  0.0000
# 2      0.0000 -0.0004  0.0000  0.0006
# 3      0.0000 -0.0003  0.0000  0.0000
# 4      0.0000 -0.0005  0.0000  0.0007
# ...       ...     ...     ...     ...
# 11245  0.0000 -0.0556  0.0000  0.0000
# 11246  0.0006 -0.0045  0.7393  0.4563
# 11247  0.0000 -0.0556  0.0000  0.0000
# 11248  0.0006 -0.0044  0.7140  0.4363
# 11249  0.0000 -0.0556  0.0000  0.0000
#
# [11250 rows x 29 columns]

# %%
# Prepare A View - Volume and Open Interest by Expiration or Strike

def filter_options_data(options, by: Literal["expiration", "strike"] = "expiration"):
    data = pd.DataFrame()
    data["Total Open Interest"] = options.groupby(by)["open_interest"].sum()
    data["Call Open Interest"] = options[options["option_type"] == "call"].groupby(by)["open_interest"].sum()
    data["Put Open Interest"] = options[options["option_type"] == "put"].groupby(by)["open_interest"].sum()
    data["Total Volume"] = options.groupby(by)["volume"].sum()
    data["Call Volume"] = options[options["option_type"] == "call"].groupby(by)["volume"].sum()
    data["Put Volume"] = options[options["option_type"] == "put"].groupby(by)["volume"].sum()

    return data

data = filter_options_data(options, "strike")

data
# Out:
#         Total Open Interest  Call Open Interest  Put Open Interest  \
# strike
# 120.0               22821.0                74.0            22747.0
# 130.0                1506.0                19.0             1487.0
# 140.0                 488.0                 2.0              486.0
# 150.0               72684.0              2072.0            70612.0
# 155.0               12298.0                18.0            12280.0
# ...                     ...                 ...                ...
# 700.0               24945.0             24835.0              110.0
# 705.0                 478.0               478.0                0.0
# 710.0                1511.0              1511.0                0.0
# 715.0                 981.0               981.0                0.0
# 720.0              102823.0            102821.0                2.0
#
#         Total Volume  Call Volume  Put Volume
# strike
# 120.0           78.0          0.0        78.0
# 130.0           61.0          0.0        61.0
# 140.0            1.0          0.0         1.0
# 150.0           65.0          4.0        61.0
# 155.0           21.0          1.0        20.0
# ...              ...          ...         ...
# 700.0            2.0          2.0         0.0
# 705.0            0.0          0.0         0.0
# 710.0            3.0          1.0         2.0
# 715.0            0.0          0.0         0.0
# 720.0           36.0         36.0         0.0
#
# [272 rows x 6 columns]

# %%
# Do not run this cell if you are following the example above.

# In this scenario, "data" could be anything that would be displayed as a bar chart. Alternatively, it could be company fundamentals data.

# Note: This requires a valid FMP API key


symbol="AAPL"

data = obb.equity.fundamental.ratios(symbol, limit = 100, period="quarter", provider="fmp")

data.index = data.index.strftime("%Y-%m-%d")

data
# Out:
#            symbol period  current_ratio  quick_ratio  cash_ratio  \
# date
# 1998-12-26   AAPL     Q1       2.605795     2.352426    0.822776
# 1999-03-27   AAPL     Q2       2.650259     2.413212    0.879534
# 1999-06-26   AAPL     Q3       2.792723     2.600390    1.152047
# 1999-09-25   AAPL     Q4       2.766301     2.522272    0.856036
# 2000-01-01   AAPL     Q1       2.498219     2.316539    0.807125
# ...           ...    ...            ...          ...         ...
# 2022-09-24   AAPL     Q4       0.879356     0.709408    0.153563
# 2022-12-31   AAPL     Q1       0.938020     0.768724    0.149578
# 2023-04-01   AAPL     Q2       0.940354     0.764281    0.205597
# 2023-07-01   AAPL     Q3       0.981563     0.813585    0.227331
# 2023-09-30   AAPL     Q4       0.988012     0.843312    0.206217
#
#             days_of_sales_outstanding  days_of_inventory_outstanding  \
# date
# 1998-12-26                  48.052632                       1.832248
# 1999-03-27                  47.294118                       1.437445
# 1999-06-26                  51.758665                       0.557029
# 1999-09-25                  45.875749                       1.890756
# 2000-01-01                  34.263764                       0.777650
# ...                               ...                            ...
# 2022-09-24                  60.833315                       8.551997
# 2022-12-31                  41.622138                       9.185598
# 2023-04-01                  34.068392                      12.738933
# 2023-07-01                  43.115762                      14.577604
# 2023-09-30                  61.327069                      11.611542
#
#             operating_cycle  days_of_payables_outstanding  \
# date
# 1998-12-26        49.884879                     48.004886
# 1999-03-27        48.731562                     63.167702
# 1999-06-26        52.315694                     63.023873
# 1999-09-25        47.766505                     76.764706
# 2000-01-01        35.041414                     60.864055
# ...                     ...                           ...
# 2022-09-24        69.385312                    110.859542
# 2022-12-31        50.807736                     78.007542
# 2023-04-01        46.807325                     73.118615
# 2023-07-01        57.693367                     92.607747
# 2023-09-30        72.938611                    114.833405
#
#             cash_conversion_cycle  ...  price_earnings_ratio  \
# date                               ...
# 1998-12-26               1.879993  ...              8.732568
# 1999-03-27             -14.436140  ...              8.397059
# 1999-06-26             -10.708179  ...              7.484225
# 1999-09-25             -28.998201  ...             23.552897
# 2000-01-01             -25.822641  ...             22.618570
# ...                           ...  ...                   ...
# 2022-09-24             -41.474230  ...             29.094281
# 2022-12-31             -27.199806  ...             17.208993
# 2023-04-01             -26.311290  ...             26.938138
# 2023-07-01             -34.914381  ...             38.288645
# 2023-09-30             -41.894793  ...             29.085850
#
#             price_to_free_cash_flows_ratio  \
# date
# 1998-12-26                       24.355053
# 1999-03-27                       18.137648
# 1999-06-26                       75.027047
# 1999-09-25                       51.769733
# 2000-01-01                       49.423264
# ...                                    ...
# 2022-09-24                      115.723695
# 2022-12-31                       68.334817
# 2023-04-01                      101.516990
# 2023-07-01                      125.370206
# 2023-09-30                      137.421101
#
#             price_to_operating_cash_flows_ratio  price_cash_flow_ratio  \
# date
# 1998-12-26                            23.808976              23.808976
# 1999-03-27                            16.856551              16.856551
# 1999-06-26                            69.058986              69.058986
# 1999-09-25                            47.970120              47.970120
# 2000-01-01                            44.388186              44.388186
# ...                                         ...                    ...
# 2022-09-24                            99.948206              99.948206
# 2022-12-31                            60.724643              60.724643
# 2023-04-01                            91.152020              91.152020
# 2023-07-01                           115.423282             115.423282
# 2023-09-30                           123.658630             123.658630
#
#             price_earnings_to_growth_ratio  price_sales_ratio  dividend_yield  \
# date
# 1998-12-26                        0.203760           3.104913        0.000000
# 1999-03-27                       -0.699755           2.963668        0.000000
# 1999-06-26                        0.178003           3.900636        0.000000
# 1999-09-25                       -0.467319           7.827460        0.000000
# 2000-01-01                        0.350588           7.066493        0.000000
# ...                                    ...                ...             ...
# 2022-09-24                        3.879237          26.750498        0.001536
# 2022-12-31                        0.369993          17.625873        0.001825
# 2023-04-01                       -1.414252          27.450564        0.001402
# 2023-07-01                       -2.253139          37.224668        0.001264
# 2023-09-30                        1.846951          29.841774        0.001407
#
#             enterprise_value_multiple  price_fair_value  calendarYear
# date
# 1998-12-26                  28.650009          2.760999          1999
# 1999-03-27                  62.597153          2.084787          1999
# 1999-06-26                 209.281398          2.046192          1999
# 1999-09-25                  70.913430          3.369035          1999
# 2000-01-01                  58.063853          3.750973          2000
# ...                               ...               ...           ...
# 2022-09-24                  90.344514         47.589406          2022
# 2022-12-31                  55.366190         36.401387          2023
# 2023-04-01                  86.117046         41.882005          2023
# 2023-07-01                 135.913479         50.517075          2023
# 2023-09-30                  92.900618         42.975881          2023
#
# [100 rows x 57 columns]

# %%
# Create a widget for selecting the data to display.

clear_output(wait = False)

data_choices = data.columns.tolist()
data_selection = widgets.Dropdown(
    options = data_choices,
    value = None,
)
output = widgets.Output()


def generate_figure(data, data_choice):
    data = data[data[data_choice].notnull()]
    fig = go.Figure()
    fig.add_bar(
        y = data[data_choice][data[data_choice] > 0].values,
        x = data[data_choice][data[data_choice] > 0].index,
        name = data_choice,
        marker = dict(color = "blue"),
    )
    fig.add_bar(
        y = data[data_choice][data[data_choice] < 0].values,
        x = data[data_choice][data[data_choice] < 0].index,
        name = data_choice,
        marker = dict(color = "red")
    )
    fig.update_xaxes(type="category")
    fig.update_traces(width=0.98, selector=dict(type="bar"))
    fig.update_layout(
        showlegend=False,
        width=1400,
        height=600,
        title = dict(
            text=f"{symbol} {data_choice.replace('_', ' ').title()}",
            xanchor = "center",
            x = 0.5,
            font = dict(size = 20)
        ),
        barmode="overlay",
        bargap=0,
        bargroupgap=0,
        yaxis=dict(
            ticklen=0,
            showgrid=True,
            tickfont=dict(size=14),
        ),
        xaxis=dict(
            showgrid=False,
            autorange=True,
            tickangle=90,
            tickfont=dict(size=11),
        ),
    )
    return fig

def on_value_change(change):
    clear_output(wait = True)
    display(data_selection)
    with output:
        data_selection.value

data_selection.observe(on_value_change, names="value")
display(data_selection)

# Select from the drop-down menu below.
# Out:
# Dropdown(options=('Total Open Interest', 'Call Open Interest', 'Put Open Interest', 'Total Volume', 'Call Volu…

# %%
# Play this cell to display the choice

if data_selection.value is not None:

    generate_figure(data, data_selection.value).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="bd364da0-3ff3-405a-a34f-67ffc2e881f9" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd364da0-3ff3-405a-a34f-67ffc2e881f9")) {                    Plotly.newPlot(                        "bd364da0-3ff3-405a-a34f-67ffc2e881f9",                        [{"marker":{"color":"blue"},"name":"Total Open Interest","x":[120.0,130.0,140.0,150.0,155.0,160.0,165.0,170.0,175.0,180.0,185.0,190.0,195.0,200.0,205.0,210.0,215.0,220.0,225.0,230.0,235.0,240.0,245.0,250.0,255.0,260.0,265.0,270.0,275.0,280.0,285.0,290.0,295.0,300.0,305.0,310.0,315.0,320.0,325.0,326.0,327.0,328.0,329.0,330.0,331.0,332.0,333.0,334.0,335.0,336.0,337.0,338.0,339.0,340.0,341.0,342.0,343.0,344.0,345.0,346.0,347.0,348.0,349.0,350.0,351.0,352.0,353.0,354.0,355.0,356.0,357.0,358.0,359.0,360.0,361.0,362.0,363.0,364.0,365.0,366.0,367.0,368.0,369.0,370.0,371.0,372.0,373.0,374.0,375.0,376.0,377.0,378.0,379.0,380.0,381.0,382.0,383.0,384.0,385.0,386.0,387.0,388.0,389.0,390.0,391.0,392.0,393.0,394.0,395.0,396.0,397.0,398.0,399.0,400.0,401.0,402.0,403.0,404.0,405.0,406.0,407.0,407.5,408.0,409.0,410.0,411.0,412.0,412.5,413.0,414.0,415.0,416.0,417.0,417.5,418.0,419.0,420.0,421.0,422.0,422.5,423.0,424.0,425.0,426.0,427.0,427.5,428.0,429.0,430.0,431.0,432.0,432.5,433.0,434.0,435.0,436.0,437.0,437.5,438.0,439.0,440.0,441.0,442.0,442.5,443.0,444.0,445.0,446.0,447.0,447.5,448.0,449.0,450.0,451.0,452.0,452.5,453.0,454.0,455.0,456.0,457.0,457.5,458.0,459.0,460.0,461.0,462.0,462.5,463.0,464.0,465.0,466.0,467.0,468.0,469.0,470.0,471.0,472.0,473.0,474.0,475.0,476.0,477.0,478.0,479.0,480.0,481.0,482.0,483.0,484.0,485.0,486.0,487.0,488.0,489.0,490.0,491.0,492.0,493.0,494.0,495.0,496.0,497.0,498.0,499.0,500.0,501.0,505.0,510.0,515.0,520.0,525.0,530.0,535.0,540.0,545.0,550.0,555.0,560.0,565.0,570.0,575.0,580.0,585.0,590.0,595.0,600.0,605.0,610.0,615.0,620.0,625.0,630.0,635.0,640.0,645.0,650.0,655.0,660.0,665.0,670.0,675.0,680.0,685.0,690.0,695.0,700.0,705.0,710.0,715.0,720.0],"y":[22821.0,1506.0,488.0,72684.0,12298.0,10083.0,10038.0,8360.0,9993.0,37606.0,32521.0,29836.0,20895.0,85139.0,24243.0,36551.0,26012.0,56622.0,23829.0,33532.0,17942.0,60632.0,35338.0,56527.0,18032.0,30316.0,30396.0,50209.0,61207.0,37026.0,50770.0,45185.0,65071.0,159070.0,53484.0,60967.0,57744.0,129600.0,109020.0,2146.0,722.0,2169.0,1340.0,133922.0,1021.0,600.0,6250.0,3915.0,98360.0,2251.0,1611.0,1133.0,1853.0,233517.0,2456.0,2804.0,2161.0,1495.0,209334.0,3899.0,5856.0,2493.0,4623.0,351448.0,6703.0,3386.0,3971.0,9834.0,239268.0,11716.0,7837.0,10534.0,13891.0,346649.0,5110.0,6728.0,4857.0,6349.0,241408.0,7327.0,17883.0,5797.0,10619.0,343956.0,7276.0,10860.0,24680.0,6971.0,285228.0,34212.0,8126.0,18856.0,12456.0,396584.0,12257.0,13430.0,15293.0,8502.0,355884.0,28496.0,8962.0,18364.0,10199.0,387739.0,19228.0,26884.0,38312.0,18468.0,317318.0,17398.0,52484.0,43708.0,20780.0,837400.0,30090.0,68012.0,59031.0,37417.0,479691.0,36668.0,72792.0,6570.0,54367.0,33032.0,413051.0,52289.0,72313.0,5688.0,86823.0,85569.0,384574.0,99860.0,47672.0,2956.0,48813.0,60772.0,573979.0,58836.0,87094.0,7284.0,83241.0,86451.0,325378.0,54454.0,82792.0,8865.0,74976.0,58801.0,554627.0,78622.0,134847.0,9534.0,84599.0,98230.0,388402.0,79630.0,78821.0,16208.0,103767.0,85884.0,579060.0,84556.0,94083.0,9933.0,84010.0,107284.0,419216.0,104896.0,157843.0,13630.0,140469.0,116466.0,580880.0,103277.0,140617.0,419.0,135349.0,135063.0,464252.0,155421.0,151442.0,264.0,132704.0,86808.0,540118.0,70502.0,95487.0,464.0,47076.0,58790.0,216515.0,45784.0,43140.0,36199.0,24123.0,227538.0,41618.0,39258.0,24366.0,25858.0,149346.0,33728.0,20640.0,22863.0,13496.0,256224.0,17288.0,18526.0,13245.0,9592.0,78595.0,6223.0,10567.0,6595.0,4966.0,102532.0,7202.0,4953.0,14529.0,119 ...
